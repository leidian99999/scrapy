# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
def get_marca_list(url):	
    request = requests.get(url)
    request.encoding="utf-8"
    soup = BeautifulSoup(request.content,"lxml")
    for i in soup.select("ul.son-menu-marca"):
        marca_url = []
        Marca_name = []
        for x in i.select("li"):
            Marca_name.append(x.text)
            marca_url.append("https://www.isdin.com" + x.a["href"])
    return marca_url,Marca_name

# %%
def get_product_list(url):
    request = requests.get(url)
    request.encoding = 'utf-8'
    soup = BeautifulSoup(request.content,'lxml')
    for i in soup.select("div.search-results"):
        title1 = []
        title2 = []
        title3 = []
        img_url = []
        vende = []
        detail_url = []
        for x in i.select('div.title_1'):
            title1.append(x.text)
        for x in i.select('div.title_2'):
            title2.append(x.text)
        for x in i.select('div.title_3'):
            title3.append(x.text)
        for x in i.select('div.vende'):
            vende.append(x.text)
        for x in i.select('div.img'):
            img_url.append(x.img["src"])
        for x in i.select('div.item'):
            detail_url.append("https://www.isdin.com" + x.a["href"])
    return title1,title2,title3,vende,img_url,detail_url

# %%
def output(dict_name,outpath,filename):
    data = pd.core.frame.DataFrame(dict_name)
    data.to_excel(outpath + filename + ".xlsx",index=False)

# %%
def get_marca_title(url):
    request = requests.get(url)
    request.encoding="utf-8"
    soup = BeautifulSoup(request.content,"lxml")
    marca_title = soup.select("ul#crumbs li")[2].text
    return marca_title

# %%
writer = r"D:\GitHub\scrapy\scrapy\project_spiders\isdin.com\test\\"
url = "https://www.isdin.com/producto/"

# %%
(marca_url,Marca_name) = get_marca_list(url)
# print("共有{}个品牌".format(len(Marca_name)))

for x in marca_url:
    print("正要开始盘" + str(x))
    (title1,title2,title3,vende,img_url,detail_url) = get_product_list(x)
    print("已经抓取完毕，准备输出！！")

    print("全体转换格式！")
    dict_list = {
        "title1":title1,
        "title2":title2,
        "title3":title3,
        "vende" :vende,
        "img_url":img_url,
        "detail_url":detail_url
    }

    marca_title  = get_marca_title(x)
    print("输出start,文件名是{}".format(marca_title))

#     print("正在输出" + str(x))
    output(dict_list,writer,marca_title)
    print("*"*50)
# Out:
# 正要开始盘https://www.isdin.com/producto/fotoprotector-isdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Fotoprotector ISDIN
# **************************************************
# 正要开始盘https://www.isdin.com/producto/foto-ultra-isdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Foto Ultra ISDIN
# **************************************************
# 正要开始盘https://www.isdin.com/producto/eryfotona
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Eryfotona
# **************************************************
# 正要开始盘https://www.isdin.com/producto/ureadin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Ureadin
# **************************************************
# 正要开始盘https://www.isdin.com/producto/maskream-cuidado-piel
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Maskream
# **************************************************
# 正要开始盘https://www.isdin.com/producto/ureadin-fusion
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Ureadin Fusion
# **************************************************
# 正要开始盘https://www.isdin.com/producto/ureadin-calm
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Ureadin Calm
# **************************************************
# 正要开始盘https://www.isdin.com/producto/woman-isdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Woman ISDIN
# **************************************************
# 正要开始盘https://www.isdin.com/producto/everclean
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Everclean
# **************************************************
# 正要开始盘https://www.isdin.com/producto/isdinceutics-productos
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Isdinceutics
# **************************************************
# 正要开始盘https://www.isdin.com/producto/germisdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Germisdin
# **************************************************
# 正要开始盘https://www.isdin.com/producto/bexident
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Bexident
# **************************************************
# 正要开始盘https://www.isdin.com/producto/nutraisdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Nutraisdin
# **************************************************
# 正要开始盘https://www.isdin.com/producto/nutracel
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Nutracel
# **************************************************
# 正要开始盘https://www.isdin.com/producto/lambdapil-anticaida
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Lambdapil Anticaída
# **************************************************
# 正要开始盘https://www.isdin.com/producto/nutratopic
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Nutratopic
# **************************************************
# 正要开始盘https://www.isdin.com/producto/antimosquitos-isdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Antimosquitos ISDIN
# **************************************************
# 正要开始盘https://www.isdin.com/producto/mupirocina-isdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Mupirocina ISDIN
# **************************************************
# 正要开始盘https://www.isdin.com/producto/antiverrugas-isdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Antiverrugas ISDIN
# **************************************************
# 正要开始盘https://www.isdin.com/producto/isdiben
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Isdiben
# **************************************************
# 正要开始盘https://www.isdin.com/producto/peroxiben
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Peroxiben
# **************************************************
# 正要开始盘https://www.isdin.com/producto/after-sun-isdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是After Sun ISDIN
# **************************************************
# 正要开始盘https://www.isdin.com/producto/bexidermil
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Bexidermil
# **************************************************
# 正要开始盘https://www.isdin.com/producto/clobisdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Clobisdin
# **************************************************
# 正要开始盘https://www.isdin.com/producto/nutradeica
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Nutradeica
# **************************************************
# 正要开始盘https://www.isdin.com/producto/vagifem
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Vagifem
# **************************************************
# 正要开始盘https://www.isdin.com/producto/activelle
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Activelle
# **************************************************
# 正要开始盘https://www.isdin.com/producto/lambdalina
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Lambdalina
# **************************************************
# 正要开始盘https://www.isdin.com/producto/antipiojos-isdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Antipiojos ISDIN
# **************************************************
# 正要开始盘https://www.isdin.com/producto/avena
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Avena
# **************************************************
# 正要开始盘https://www.isdin.com/producto/acniben-repair
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Acniben Repair
# **************************************************
# 正要开始盘https://www.isdin.com/producto/acniben
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Acniben
# **************************************************
# 正要开始盘https://www.isdin.com/producto/psorisdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Psorisdin
# **************************************************
# 正要开始盘https://www.isdin.com/producto/medicis
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Medicis
# **************************************************
# 正要开始盘https://www.isdin.com/producto/hongoseril
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Hongoseril
# **************************************************
# 正要开始盘https://www.isdin.com/producto/amorolfina-isdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Amorolfina ISDIN
# **************************************************
# 正要开始盘https://www.isdin.com/producto/ciclopirox-isdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Ciclopirox ISDIN
# **************************************************
# 正要开始盘https://www.isdin.com/producto/bonalfa
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Bonalfa
# **************************************************
# 正要开始盘https://www.isdin.com/producto/nutrasona
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Nutrasona
# **************************************************
# 正要开始盘https://www.isdin.com/producto/hidrocisdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Hidrocisdin
# **************************************************
# 正要开始盘https://www.isdin.com/producto/ketoisdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Ketoisdin
# **************************************************
# 正要开始盘https://www.isdin.com/producto/tactuoben
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Tactuoben
# **************************************************
# 正要开始盘https://www.isdin.com/producto/eviana
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Eviana
# **************************************************
# 正要开始盘https://www.isdin.com/producto/cicapost-isdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Cicapost ISDIN
# **************************************************
# 正要开始盘https://www.isdin.com/producto/dermedica
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Dermédica
# **************************************************
# 正要开始盘https://www.isdin.com/producto/fungisdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Fungisdin
# **************************************************
# 正要开始盘https://www.isdin.com/producto/duofemme
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Duofemme
# **************************************************
# 正要开始盘https://www.isdin.com/producto/calcio-d
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Calcio D
# **************************************************
# 正要开始盘https://www.isdin.com/producto/acido-fusidico
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Ácido fusídico
# **************************************************
# 正要开始盘https://www.isdin.com/producto/ciclopirox-olamina
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Ciclopirox olamina
# **************************************************
# 正要开始盘https://www.isdin.com/producto/flunutrac
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Flunutrac
# **************************************************
# 正要开始盘https://www.isdin.com/producto/glicoisdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Glicoisdin
# **************************************************
# 正要开始盘https://www.isdin.com/producto/quocin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Quocin
# **************************************************
# 正要开始盘https://www.isdin.com/producto/lambdaxel
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Lambdaxel
# **************************************************
# 正要开始盘https://www.isdin.com/producto/trisequens
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Trisequens
# **************************************************
# 正要开始盘https://www.isdin.com/producto/retisdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Retisdin
# **************************************************
# 正要开始盘https://www.isdin.com/producto/citroband-isdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是CitroBand ISDIN
# **************************************************
# 正要开始盘https://www.isdin.com/producto/finastopic-productos
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Finastopic
# **************************************************
# 正要开始盘https://www.isdin.com/producto/desirial
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Desirial
# **************************************************
# 正要开始盘https://www.isdin.com/producto/isdin-deo
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是ISDIN Deo
# **************************************************
# 正要开始盘https://www.isdin.com/producto/labiales-isdin
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Labiales ISDIN
# **************************************************
# 正要开始盘https://www.isdin.com/producto/micellar-solution
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Micellar Solution
# **************************************************
# 正要开始盘https://www.isdin.com/producto/isdin-shampoo
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是ISDIN Shampoo
# **************************************************
# 正要开始盘https://www.isdin.com/producto/verrutop
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Verrutop
# **************************************************
# 正要开始盘https://www.isdin.com/producto/ketopirox
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Ketopirox
# **************************************************
# 正要开始盘https://www.isdin.com/producto/itragerm
# 已经抓取完毕，准备输出！！
# 全体转换格式！
# 输出start,文件名是Itragerm
# **************************************************
